# %%
img1=input("Enter image")
img2=input("Output image")
# Out:
# Enter image nana.jpg
# Output image newoutput.jpg

# %% [markdown]
# # Negative of an Image
#
# import numpy as np
# import matplotlib.pyplot as plt

# %%
d=plt.imread(img1)

# %%
m=np.max(d)
d2=m-d

plt.imshow(d2)
plt.show()
