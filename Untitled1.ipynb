# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img1=input("Enter your RGB file name")
img2=input("Enter your output file name")
# Out:
# Enter your RGB file name nana.jpg
# Enter your output file name output1.jpg

# %%
data1=plt.imread(img1)

# %%
shape1=data1.shape

# %%
r1,c1,d1=shape1

# %%
print("r1=",r1,"c1=",c1,"d1=",d1)
# Out:
# r1= 1176 c1= 736 d1= 3

# %%
print(data1)
# Out:
# [[[101 101 109]
#   [101 101 109]
#   [101 101 109]
#   ...
#   [ 12  36  10]
#   [ 72  98  59]
#   [113 140  95]]
#
#  [[ 93  93 101]
#   [ 93  93 101]
#   [ 93  93 101]
#   ...
#   [ 38  63  34]
#   [ 89 115  76]
#   [108 135  90]]
#
#  [[ 93  93 101]
#   [ 94  94 102]
#   [ 94  94 102]
#   ...
#   [ 72  97  67]
#   [104 131  90]
#   [ 99 127  79]]
#
#  ...
#
#  [[ 95  61  96]
#   [ 96  60  98]
#   [ 96  60  98]
#   ...
#   [ 15  28  21]
#   [ 15  28  21]
#   [ 15  28  21]]
#
#  [[ 96  60  98]
#   [ 96  59 100]
#   [ 97  59 100]
#   ...
#   [ 17  30  23]
#   [ 17  30  23]
#   [ 17  30  23]]
#
#  [[ 98  60 101]
#   [ 97  58 102]
#   [ 99  58 102]
#   ...
#   [ 18  31  24]
#   [ 18  31  24]
#   [ 18  31  24]]]

# %%
plt.imshow(data1)

# %%
plt.savefig(img2)

# %%
plt.show()
