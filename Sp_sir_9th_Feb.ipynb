# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\hp\appdata\roaming\python\python312\site-packages (4.13.0.92)
# Collecting numpy>=2 (from opencv-python)
#   Using cached numpy-2.4.2-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.2-cp312-cp312-win_amd64.whl (12.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-2.4.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\HP\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.4.2 which is incompatible.
# numba 0.59.1 requires numpy<1.27,>=1.22, but you have numpy 2.4.2 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.4.2 which is incompatible.
# scipy 1.13.1 requires numpy<2.3,>=1.22.4, but you have numpy 2.4.2 which is incompatible.
# streamlit 1.32.0 requires numpy<2,>=1.19.3, but you have numpy 2.4.2 which is incompatible.

# %%
import cv2
print(cv2.__version__)
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 4.13.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 4
#       2 print(cv2.__version__)
#       3 import numpy as np
# ----> 4 import matplotlib.pyplot as plt
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:963
#     957     return config
#     960 # When constructing the global instances, we need to perform certain updates
#     961 # by explicitly calling the superclass (dict.update, dict.items) to avoid
#     962 # triggering resolution of _auto_backend_sentinel.
# --> 963 rcParamsDefault = _rc_params_in_file(
#     964     cbook._get_data_path("matplotlibrc"),
#     965     # Strip leading comment.
#     966     transform=lambda line: line[1:] if line.startswith("#") else line,
#     967     fail_on_error=True)
#     968 dict.update(rcParamsDefault, rcsetup._hardcoded_defaults)
#     969 # Normally, the default matplotlibrc file contains *no* entry for backend (the
#     970 # corresponding line starts with ##, not #; we fill on _auto_backend_sentinel
#     971 # in that case.  However, packagers can set a different default backend
#     972 # (resulting in a normal `#backend: foo` line) in which case we should *not*
#     973 # fill in _auto_backend_sentinel.
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:897, in _rc_params_in_file(fname, transform, fail_on_error)
#     895 if key in rcsetup._validators:
#     896     if fail_on_error:
# --> 897         config[key] = val  # try to convert to proper type or raise
#     898     else:
#     899         try:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:732, in RcParams.__setitem__(self, key, val)
#     730             return
#     731 try:
# --> 732     cval = self.validate[key](val)
#     733 except ValueError as ve:
#     734     raise ValueError(f"Key {key}: {ve}") from None
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\rcsetup.py:317, in validate_color(s)
#     314         if is_color_like(stmp):
#     315             return stmp
# --> 317 if is_color_like(s):
#     318     return s
#     320 # If it is still valid, it must be a tuple (as a string from matplotlibrc).
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py:227, in is_color_like(c)
#     225     return True
#     226 try:
# --> 227     to_rgba(c)
#     228 except ValueError:
#     229     return False
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py:302, in to_rgba(c, alpha)
#     300     rgba = None
#     301 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 302     rgba = _to_rgba_no_colorcycle(c, alpha)
#     303     try:
#     304         _colors_full_map.cache[c, alpha] = rgba
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\colors.py:329, in _to_rgba_no_colorcycle(c, alpha)
#     327     raise ValueError("'alpha' must be between 0 and 1, inclusive")
#     328 orig_c = c
# --> 329 if c is np.ma.masked:
#     330     return (0., 0., 0., 0.)
#     331 if isinstance(c, str):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\__init__.py:737, in __getattr__(attr)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\ma\__init__.py:42
#       1 """
#       2 =============
#       3 Masked Arrays
#    (...)
#      40
#      41 """
# ---> 42 from . import core
#      43 from .core import *
#      45 from . import extras
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\ma\core.py:33
#      31 import numpy as np
#      32 import numpy.core.umath as umath
# ---> 33 import numpy.core.numerictypes as ntypes
#      34 from numpy.core import multiarray as mu
#      35 from numpy import ndarray, amax, amin, iscomplexobj, bool_, _NoValue
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\numerictypes.py:105
#      99 # we don't need all these imports, but we need to keep them for compatibility
#     100 # for users using np.core.numerictypes.UPPER_TABLE
#     101 from ._string_helpers import (
#     102     english_lower, english_upper, english_capitalize, LOWER_TABLE, UPPER_TABLE
#     103 )
# --> 105 from ._type_aliases import (
#     106     sctypeDict,
#     107     allTypes,
#     108     bitname,
#     109     sctypes,
#     110     _concrete_types,
#     111     _concrete_typeinfo,
#     112     _bits_of,
#     113 )
#     114 from ._dtype import _kind_name
#     116 # we don't export these for import *, but we do want them accessible
#     117 # as numerictypes.bool, etc.
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\_type_aliases.py:121
#     117         # add mapping for both the bit name
#     118         sctypeDict[myname] = info.type
# --> 121 _add_aliases()
#     123 def _add_integer_aliases():
#     124     seen_bits = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\_type_aliases.py:101, in _add_aliases()
#      98     continue
#     100 # insert bit-width version for this class (if relevant)
# --> 101 base, bit, char = bitname(info.type)
#     103 myname = "%s%d" % (base, bit)
#     105 # ensure that (c)longdouble does not overwrite the aliases assigned to
#     106 # (c)double
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\_type_aliases.py:60, in bitname(obj)
#      58 def bitname(obj):
#      59     """Return a bit-width name for a given type object"""
# ---> 60     bits = _bits_of(obj)
#      61     dt = dtype(obj)
#      62     char = dt.kind
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\_type_aliases.py:55, in _bits_of(obj)
#      53     return dtype(obj).itemsize * 8
#      54 else:
# ---> 55     return info.bits
#
# AttributeError: 'numpy.dtypes.BoolDType' object has no attribute 'bits'

# %%
img=cv2.imread(r'C:\Users\HP\Desktop\chayan\charizard.jpg')

# %%
print(img)
# Out:
# [[[  5   8  82]
#   [  5   8  82]
#   [  5   9  80]
#   ...
#   [  1   2   0]
#   [  3   3   0]
#   [  3   4   0]]
#
#  [[  6   9  83]
#   [  5   8  82]
#   [  5   9  80]
#   ...
#   [  1   2   0]
#   [  3   3   0]
#   [  3   4   0]]
#
#  [[  6   9  84]
#   [  6   9  83]
#   [  3   9  80]
#   ...
#   [  1   2   0]
#   [  1   2   0]
#   [  1   3   0]]
#
#  ...
#
#  [[ 44  63 250]
#   [ 46  65 252]
#   [ 47  66 253]
#   ...
#   [ 55  63 210]
#   [ 59  68 212]
#   [ 61  70 214]]
#
#  [[ 44  63 250]
#   [ 46  65 252]
#   [ 47  66 253]
#   ...
#   [ 56  64 208]
#   [ 60  69 210]
#   [ 62  72 210]]
#
#  [[ 44  63 250]
#   [ 46  65 252]
#   [ 47  66 253]
#   ...
#   [ 57  64 205]
#   [ 60  70 207]
#   [ 62  74 206]]]

# %%
print(img.shape)
# Out:
# (1309, 736, 3)

# %%
print(img.dtype)
# Out:
# uint8

# %%
print(img.size)
# Out:
# 2890272

# %%
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.imshow(img)
#
# NameError: name 'plt' is not defined
