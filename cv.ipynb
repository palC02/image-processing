# %%
import cv2

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
img2=cv2.imread(r'C:\Users\HP\Desktop\chayan\charizard.jpg')

# %%
print(img2)
# Out:
# [[[  5   8  82]
#   [  5   8  82]
#   [  5   9  80]
#   ...
#   [  1   2   0]
#   [  3   3   0]
#   [  3   4   0]]
#
#  [[  6   9  83]
#   [  5   8  82]
#   [  5   9  80]
#   ...
#   [  1   2   0]
#   [  3   3   0]
#   [  3   4   0]]
#
#  [[  6   9  84]
#   [  6   9  83]
#   [  3   9  80]
#   ...
#   [  1   2   0]
#   [  1   2   0]
#   [  1   3   0]]
#
#  ...
#
#  [[ 44  63 250]
#   [ 46  65 252]
#   [ 47  66 253]
#   ...
#   [ 55  63 210]
#   [ 59  68 212]
#   [ 61  70 214]]
#
#  [[ 44  63 250]
#   [ 46  65 252]
#   [ 47  66 253]
#   ...
#   [ 56  64 208]
#   [ 60  69 210]
#   [ 62  72 210]]
#
#  [[ 44  63 250]
#   [ 46  65 252]
#   [ 47  66 253]
#   ...
#   [ 57  64 205]
#   [ 60  70 207]
#   [ 62  74 206]]]

# %%
print(img2.shape)
# Out:
# (1309, 736, 3)

# %%
print(img2.dtype)
# Out:
# uint8

# %%
print(img2.size)
# Out:
# 2890272

# %%
plt.imshow(img2)

# %%
img=cv2.imread(r'C:\Users\HP\Desktop\chayan\moon.jpg')
R,G,B=img[:,:,0],img[:,:,1],img[:,:,2]
if(R==G).all() and (G==B).all():
    print('GrayScale Image')
else:
    print('RGB')

plt.imshow(img)
plt.axis('off')
# Out:
# GrayScale Image
# (-0.5, 1399.5, 1208.5, -0.5)

# %%
from skimage import img_as_float

# %%
img2=img_as_float(img)

# %%
print(img2.max())
print(img2.min())
# Out:
# 1.0
# 0.0

# %%
print(img2.shape)
# Out:
# (1209, 1400, 3)

# %%
import os

# %%
folder=r"\Users\HP\Desktop\chayan\Image Processing 2026 @ MSc SEM IV\images"
for files in os.listdir(folder):
    img=cv2.imread(os.path.join(folder,files))
    print(img.shape)
# Out:
# (589, 953, 3)
# (490, 487, 3)
# (1600, 1600, 3)
# (512, 512, 3)
# (512, 512, 3)
# (707, 749, 3)
# (520, 732, 3)
# (1209, 1400, 3)
# (1209, 1400, 3)
# (1209, 1400, 3)
# (480, 512, 3)
# (707, 749, 3)
# (707, 749, 3)
# (4000, 6000, 3)
# (737, 974, 3)
